# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **`Mohammad Ghavi`**

# %% [markdown]
# https://dm0qx8t0i9gc9.cloudfront.net/thumbnails/video/MPaEbz-/slow-motion-video-of-smiling-parachutist-man-in-white-helmet-and-gear-flying-free-fall-with-his-arm-forward-in-superhero-pose-side-and-front-view-chroma-key-against-green-screen-background_sr4qkbws__d_thumbnail-180_01.jpg

# %%
img = cv2.imread(r'chroma key.jpg')
im_ar = np.array(img)

# %%
im_ar.shape
# Out:
# (180, 320, 3)

# %%
# im_ar[:,:,1], im_ar[:,:,2] = im_ar[:,:,2], im_ar[:,:,1]
# im_ar[:,:,1], im_ar[:,:,0] = im_ar[:,:,0], im_ar[:,:,1]
im_ar[:,:,2], im_ar[:,:,0] = im_ar[:,:,0], im_ar[:,:,2]

# %%
fig = plt.figure(figsize=(12,3))
ax1 = fig.add_axes([0.1,5,1,1])
ax2 = fig.add_axes([0.9,5,1,1])
ax1.imshow(im_ar)
ax2.hist(np.ravel(im_ar), bins=np.arange(0,256));

# %%
im_ar[im_ar<=15] = 255 # Threshold == 10

# %%
fig = plt.figure(figsize=(12,3))
ax1 = fig.add_axes([0.1,5,1,1])
ax2 = fig.add_axes([0.9,5,1,1])
ax1.imshow(im_ar)
ax2.hist(np.ravel(im_ar), bins=np.arange(0,256));
